# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# ubah nama kolom
df = df.rename(columns = {'Gender': 'gender', 'Age': 'age',
                          'Annual Income (k$)': 'annual_income',
                          'Spending Score (1-100)': 'spending_score'})

# ubah data kategorik -> data numerik
df['gender'].replace(['Female', 'Male'], [0,1], inplace=True)

# tampilkan data
df.head(3)
# Out:
#    CustomerID  gender  age  annual_income  spending_score
# 0           1       1   19             15              39
# 1           2       1   21             15              81
# 2           3       0   20             16               6

# %%
from sklearn.cluster import KMeans

# menghilangkan kolom id dan gender
X = df.drop(['CustomerID', 'gender'], axis=1)

# membuat list yang berisi inertia
clusters = []
for i in range(1,11):
    km = KMeans(n_clusters=i).fit(X)
    clusters.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# membuat plot inertia
fig, ax = plt.subplots(figsize=(8, 4))
sns.lineplot(x=list(range(1,11)), y=clusters, ax=ax)
ax.set_title('Cari Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
# membuat objek KMeans
km5 = KMeans(n_clusters=5).fit(X)

# menambahkan kolom pada label
X['Labels'] = km.labels_

# membuat plot KMeans dengan 5 klaster
plt.figure(figsize=(8,4))
sns.scatterplot(X['annual_income'], X['spending_score'], hue=X['Labels'],
                palette=sns.color_palette('hls', 5))
plt.title('KMeans dengan 5 Cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0cc4c814a46e> in <module>
#       8 plt.figure(figsize=(8,4))
#       9 sns.scatterplot(X['annual_income'], X['spending_score'], hue=X['Labels'],
# ---> 10                 palette=sns.color_palette('hls', 4))
#      11 plt.title('KMeans dengan 5 Cluster')
#      12 plt.show()
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1395         x_bins=x_bins, y_bins=y_bins,
#    1396         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1397         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1398     )
#    1399
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     891         )
#     892
# --> 893         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     894         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     895         self.parse_style(plot_data["style"], markers, None, style_order)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/relational.py in parse_hue(self, data, palette, order, norm)
#     371                 # overcome differences in the way pandas
#     372                 # externalizes numpy datetime64
# --> 373                 list(data), order, palette
#     374             )
#     375
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/seaborn/relational.py in categorical_to_palette(self, data, order, palette)
#     214                 if len(palette) != n_colors:
#     215                     err = "The palette list has the wrong number of colors."
# --> 216                     raise ValueError(err)
#     217                 colors = palette
#     218             else:
#
# ValueError: The palette list has the wrong number of colors.
